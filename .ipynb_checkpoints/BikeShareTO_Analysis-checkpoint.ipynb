# %%
import pandas as pd
import numpy as np
import requests
import json
import sqlite3
import datetime
import seaborn as sns

# %% [markdown]
# Import bike station information.

# %%
url2='https://tor.publicbikesystem.net/ube/gbfs/v1/en/station_information'
stationInfo_df = pd.DataFrame(json.loads(requests.get(url2).text)['data']['stations'])
stationInfo_df['station_id'] = stationInfo_df['station_id'].astype(np.int64)
stationInfo_df.head()
# Out:
#    station_id                             name physical_configuration  \
# 0        7000     Fort York  Blvd / Capreol Ct                REGULAR
# 1        7001  Lower Jarvis St / The Esplanade                REGULAR
# 2        7002       St. George St / Bloor St W                REGULAR
# 3        7003         Madison Ave / Bloor St W                REGULAR
# 4        7004          University Ave / Elm St                REGULAR
#
#          lat        lon  altitude                          address  capacity  \
# 0  43.639832 -79.395954       0.0     Fort York  Blvd / Capreol Ct        35
# 1  43.647992 -79.370907       0.0  Lower Jarvis St / The Esplanade        15
# 2  43.667333 -79.399429       0.0       St. George St / Bloor St W        19
# 3  43.667158 -79.402761       NaN         Madison Ave / Bloor St W        15
# 4  43.656518 -79.389099       NaN          University Ave / Elm St        11
#
#                           rental_methods        groups          obcn  \
# 0  [KEY, CREDITCARD, TRANSITCARD, PHONE]            []  647-643-9607
# 1  [KEY, CREDITCARD, TRANSITCARD, PHONE]            []  416-617-9576
# 2  [KEY, CREDITCARD, TRANSITCARD, PHONE]            []  647-643-9615
# 3  [KEY, CREDITCARD, TRANSITCARD, PHONE]            []  647-631-4587
# 4  [KEY, CREDITCARD, TRANSITCARD, PHONE]  [P7004-7047]  647-643-9673
#
#    nearby_distance post_code cross_street
# 0            500.0       NaN          NaN
# 1            500.0       NaN          NaN
# 2            500.0       NaN          NaN
# 3            500.0       NaN          NaN
# 4            500.0       NaN          NaN

# %% [markdown]
# Connect to the SQLite database. This contains a log of all station statuses that is recored every 10 minutes.

# %%
conn = sqlite3.connect('bikeshareTO.db')
c = conn.cursor()

# %% [markdown]
# Load the database into a pandas dataframe.

# %%
df = pd.read_sql_query(
    'SELECT * FROM station_status',conn)

# %% [markdown]
# I'm going to check which stations has the largest standard deviation as an indicator of activity.

# %%
busyStations_df = df[['station_id','num_bikes_available']].groupby(by='station_id').std().sort_values(by='num_bikes_available',ascending=False).head(20)
busyStations_df.join(stationInfo_df[['station_id','name']].set_index('station_id'))
# Out:
#             num_bikes_available                                   name
# station_id
# 7344                  13.080138                           Cherry Beach
# 7047                   9.418428          University Ave / Gerrard St W
# 7042                   9.208683         Sherbourne St / Wellesley St E
# 7168                   8.833212                 Queens Quay / Yonge St
# 7015                   8.418153         King St W / Bay St (West Side)
# 7037                   8.411136              Bathurst St / Dundas St W
# 7000                   7.581542           Fort York  Blvd / Capreol Ct
# 7524                   7.446355                            Lisgar Park
# 7161                   7.153509               Beverley St / College St
# 7533                   7.025474     Housey St / Dan Leckie Way - SMART
# 7101                   6.291144    Lower Sherbourne St / The Esplanade
# 7052                   6.204093               Wellington St W / Bay St
# 7100                   6.100131         Dundas St E / Regent Park Blvd
# 7121                   6.096291                Jarvis St / Dundas St E
# 7002                   6.088992             St. George St / Bloor St W
# 7502                   5.853565     University Ave / College St (East)
# 7601                   5.809747                            Brick Works
# 7518                   5.763757  Lake Shore Blvd W / Colborne Lodge Dr
# 7072                   5.691470                 Fleet St / Bathurst St
# 7220                   5.617275           Lakeshore Blvd W / Ellis Ave

# %% [markdown]
# For Cherry Beach, the bikes begin to get rented around 12pm.

# %%
df = pd.read_sql_query(
    'SELECT * FROM station_status WHERE station_id=7344',conn)
df['last_reported'] = pd.to_datetime(df['last_reported'],unit='s') + pd.Timedelta(hours=-4)
ax = df.plot('last_reported','num_bikes_available',figsize=(10,5))
ax.set_xlabel('Date (M-D-Hour)')
# Out:
# Text(0.5, 0, 'Date (M-D-Hour)')

# %% [markdown]
# For University Ave / Gerrard St W, the clear 8am-4pm work cycle is shown.

# %%
df = pd.read_sql_query(
    'SELECT * FROM station_status WHERE station_id=7047',conn)
df['last_reported'] = pd.to_datetime(df['last_reported'],unit='s') + pd.Timedelta(hours=-4)
ax = df.plot('last_reported','num_bikes_available',figsize=(10,5))
ax.set_xlabel('Date (M-D-Hour)')
# Out:
# Text(0.5, 0, 'Date (M-D-Hour)')

# %%
df2['name'].str.contains('Fort')
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 54586    False
# 54587    False
# 54588    False
# 54589    False
# 54590    False
# Name: name, Length: 54591, dtype: object

# %% [markdown]
# I'm going to analyze the difference between bike availability before the beginning of the work cycle (4am - 6am) and during the start of the work cycle (8am - 10am). This will indicate where people are going.

# %%
df = pd.read_sql_query(
    'SELECT * FROM station_status',conn)
df['last_reported'] = pd.to_datetime(df['last_reported'],unit='s') + pd.Timedelta(hours=-4)
startHours = (df['last_reported']<'10:00:00') & (df['last_reported']>'8:00:00')
earlyHours = (df['last_reported']<'2020-08-20 6:00:00') & (df['last_reported']>'2020-08-20 4:00:00')
endHours = (df['last_reported']<'2020-08-20 19:00:00') & (df['last_reported']>'2020-08-20 17:00:00')
start_df = df[startHours].groupby(by='station_id').mean()
end_df = df[endHours].groupby(by='station_id').mean()
start_df
# Out:
#             num_bikes_available  num_bikes_disabled  num_docks_available
# station_id
# 7000                  29.500000            0.000000             5.500000
# 7001                   9.416667            0.000000             5.583333
# 7002                  10.500000            0.000000             8.500000
# 7003                   1.833333            1.916667            11.250000
# 7004                  10.833333            0.166667             0.000000
# ...                         ...                 ...                  ...
# 7640                   0.000000            0.000000            15.000000
# 7641                   6.000000            0.000000             9.000000
# 7642                   0.416667            0.000000            18.583333
# 7643                   8.750000            0.000000            10.250000
# 7644                  10.750000            0.000000             4.250000
#
# [582 rows x 3 columns]

# %%
early_df = df[earlyHours].groupby(by='station_id').mean()
early_df
# Out:
#             num_bikes_available  num_bikes_disabled  num_docks_available
# station_id
# 7000                       33.0                 0.0                  2.0
# 7001                       14.0                 0.0                  1.0
# 7002                        0.0                 0.0                 19.0
# 7003                        4.0                 1.0                 10.0
# 7004                        4.0                 0.0                  7.0
# ...                         ...                 ...                  ...
# 7640                        0.0                 0.0                 15.0
# 7641                        6.0                 0.0                  9.0
# 7642                        2.0                 0.0                 17.0
# 7643                        8.0                 0.0                 11.0
# 7644                       11.0                 0.0                  4.0
#
# [582 rows x 3 columns]

# %% [markdown]
# I'll subtract the results of the dataframes to get the average change in bike availabilty at each station. I divide the result by the capacity to normalize the results.

# %%
diff_df = (start_df - early_df).sort_values(by='num_bikes_available').join(stationInfo_df.set_index('station_id')[['name','capacity','lat','lon']])
diff_df['normalized_change'] = np.rint(diff_df['num_bikes_available']/ diff_df['capacity']*100)
diff_df = diff_df.sort_values(by='normalized_change')
diff_df
# Out:
#             num_bikes_available  num_bikes_disabled  num_docks_available  \
# station_id
# 7017                  -7.903846            0.000000             7.903846
# 7054                  -7.384615            0.000000             7.384615
# 7168                 -20.141026            0.000000            20.141026
# 7278                  -9.500000            0.000000             9.500000
# 7525                  -4.000000            0.000000             4.000000
# ...                         ...                 ...                  ...
# 7062                   7.500000            0.000000            -7.500000
# 7026                  10.500000            1.000000           -11.500000
# 7047                  18.272727            0.363636           -18.636364
# 7015                  14.166667            0.000000           -14.166667
# 7502                  12.643939            0.000000           -12.643939
#
#                                           name  capacity        lat  \
# station_id
# 7017                 Widmer St / Adelaide St W        11  43.647508
# 7054            Navy Wharf Ct. / Bremner Blvd.        11  43.640722
# 7168                    Queens Quay / Yonge St        31  43.641646
# 7278             Mallon Ave / Jones Ave -SMART        16  43.665870
# 7525          Fennings St / Queen St W - SMART         7  43.643945
# ...                                        ...       ...        ...
# 7062        University Ave / College St (West)        11  43.659226
# 7026                    Bay St / St. Joseph St        15  43.665527
# 7047             University Ave / Gerrard St W        25  43.657763
# 7015            King St W / Bay St (West Side)        19  43.648520
# 7502        University Ave / College St (East)        14  43.659950
#
#                   lon  normalized_change
# station_id
# 7017       -79.391484              -72.0
# 7054       -79.391051              -67.0
# 7168       -79.375308              -65.0
# 7278       -79.334430              -59.0
# 7525       -79.421189              -57.0
# ...               ...                ...
# 7062       -79.390213               68.0
# 7026       -79.387499               70.0
# 7047       -79.389165               73.0
# 7015       -79.380576               75.0
# 7502       -79.389640               90.0
#
# [582 rows x 8 columns]

# %% [markdown]
# ## Map
# I'll plot the results on a Folium map, where the red data points indicate stations that had a deficit of bikes and the green points represent the stations that had a surplus of bikes. The size of the markers represents the magnitude of the normalized change.
#
# We can clearly see that the green (surplus) data points are centralized whereas the deficit are outside the downtown core and outskirts. The surplus is mainly clustered on University Avenue near the hospitals, and on Bay street by the Financial district.

# %%
import folium

m = folium.Map(location=[43.650033,-79.396555])
diff_df[diff_df['normalized_change']<=-5].apply(lambda row:folium.Circle(location=[row["lat"], 
                                                  row["lon"]], color='#FF0000', radius=np.abs(row['normalized_change']),fill=True, 
                                                                          tooltip=row['name']+"<br>Capacity Change: "+str(row['normalized_change'])+"%<br> Capacity: "+str(row['capacity'])+"<br>Net Bikes: "+str(np.rint(row['num_bikes_available']))).add_to(m),
         axis=1)

diff_df[diff_df['normalized_change']>=5].apply(lambda row:folium.Circle(location=[row["lat"], 
                                                  row["lon"]], color='#008000', radius=np.abs(row['normalized_change']),fill=True, 
                                                                         tooltip=row['name']+"<br>Capacity Change: "+str(row['normalized_change'])+"%<br> Capacity: "+str(row['capacity'])+"<br>Net Bikes: "+str(np.rint(row['num_bikes_available']))).add_to(m),
         axis=1)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# I'll do a similar analysis comparing the end of work hours (5pm-7pm) compared to the start of work hours (8am-10am).

# %%
diff_df = (end_df - start_df).sort_values(by='num_bikes_available').join(stationInfo_df.set_index('station_id')[['name','capacity','lat','lon']])
diff_df['normalized_change'] = np.rint(diff_df['num_bikes_available']/ diff_df['capacity']*100)
diff_df = diff_df.sort_values(by='normalized_change')
diff_df
# Out:
#             num_bikes_available  num_bikes_disabled  num_docks_available  \
# station_id
# 7502                 -12.602273            0.000000            12.602273
# 7047                 -21.522727            1.636364            19.886364
# 7344                 -40.000000            0.000000            40.000000
# 7004                  -8.958333            0.833333             8.125000
# 7006                  -8.791667            0.000000             8.791667
# ...                         ...                 ...                  ...
# 7029                   7.541667            0.000000            -7.541667
# 7063                   9.541667            0.000000            -9.541667
# 7409                  10.666667            0.000000           -10.666667
# 7170                   9.125000            0.000000            -9.125000
# 7418                  15.791667            0.000000           -15.791667
#
#                                           name  capacity        lat  \
# station_id
# 7502        University Ave / College St (East)        14  43.659950
# 7047             University Ave / Gerrard St W        25  43.657763
# 7344                              Cherry Beach        49  43.637764
# 7004                   University Ave / Elm St        11  43.656518
# 7006           Bay St / College St (East Side)        11  43.660439
# ...                                        ...       ...        ...
# 7029           Bay St / Bloor St W (East Side)        15  43.669430
# 7063                 Queen's Park / Bloor St W        19  43.668456
# 7409                   Isabella St / Church St        19  43.668340
# 7170                Spadina Ave / Willcocks St        15  43.661667
# 7418          College Park - Yonge St Entrance        24  43.659880
#
#                   lon  normalized_change
# station_id
# 7502       -79.389640              -90.0
# 7047       -79.389165              -86.0
# 7344       -79.345359              -82.0
# 7004       -79.389099              -81.0
# 7006       -79.385525              -80.0
# ...               ...                ...
# 7029       -79.389150               50.0
# 7063       -79.393899               50.0
# 7409       -79.382350               56.0
# 7170       -79.401389               61.0
# 7418       -79.382790               66.0
#
# [582 rows x 8 columns]

# %% [markdown]
# We can start to see some green points on the outskirts indicating that people are leaving work. A significant deficit is seen on University Ave as well.

# %%
m = folium.Map(location=[43.650033,-79.396555])
diff_df[diff_df['normalized_change']<=-5].apply(lambda row:folium.Circle(location=[row["lat"], 
                                                  row["lon"]], color='#FF0000', radius=np.abs(row['normalized_change']),fill=True, 
                                                                          tooltip=row['name']+"<br>Capacity Change: "+str(row['normalized_change'])+"%<br> Capacity: "+str(row['capacity'])+"<br>Net Bikes: "+str(np.rint(row['num_bikes_available']))).add_to(m),
         axis=1)

diff_df[diff_df['normalized_change']>=5].apply(lambda row:folium.Circle(location=[row["lat"], 
                                                  row["lon"]], color='#008000', radius=np.abs(row['normalized_change']),fill=True, 
                                                                         tooltip=row['name']+"<br>Capacity Change: "+str(row['normalized_change'])+"%<br> Capacity: "+str(row['capacity'])+"<br>Net Bikes: "+str(np.rint(row['num_bikes_available']))).add_to(m),
         axis=1)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
